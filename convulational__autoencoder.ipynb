# %% [markdown]
# # Objective
# To build a convolutional Autoencoder (CAE) that compresses facial images into a lower dimensional latent representation and then reconstructs them with minimal loss of information
#
# # Purpose
#
# A convolutional autoencoder is an unsupervised deep learning model used for :
# Image compression image reconstruction feature extraction dimensionality reduction
# the encoder learns a compressed representation (latent space),while the decoder learns to reconstruct the original image from this compressed representation

# %%
# Libraries
import os
import shutil
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.layers import Input , BatchNormalization
from tensorflow.keras.models import Model

# %%
# Loading dataset

import kagglehub

# Download latest version
path = kagglehub.dataset_download("jessicali9530/celeba-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'celeba-dataset' dataset.
# Path to dataset files: /kaggle/input/celeba-dataset

# %%
# create a smaller dataset
source_folder = os.path.join(path, 'img_align_celeba', 'img_align_celeba')
destination_folder = "celeba_small/faces"
os.makedirs(destination_folder, exist_ok=True)
images = sorted(os.listdir(source_folder))[:5000]
for img in images:
    shutil.copy(
        os.path.join(source_folder, img),
        destination_folder
        )

print("Copied", len(images),"images")
# Out:
# Copied 5000 images

# %%
# # Upload kaggle API
# from google.colab import files
# files.upload()

# %%
# DATA PREPROCESSING
IMAGE_SIZE = (64,64)

BATCH_SIZE = 32

# %%
datagen = ImageDataGenerator(
    rescale = 1./255,
    validation_split = 0.2
)

# %%
validation_generator = datagen.flow_from_directory(
    "celeba_small",
    target_size = IMAGE_SIZE,
    batch_size = BATCH_SIZE,
    class_mode = "input",
    subset = "validation"
)
# Out:
# Found 1000 images belonging to 1 classes.

# %%
train_generator = datagen.flow_from_directory(
    "celeba_small",
    target_size = IMAGE_SIZE,
    batch_size = BATCH_SIZE,
    class_mode = "input",
    subset = "training"
)
# Out:
# Found 4000 images belonging to 1 classes.

# %%
images, _ = next(train_generator)
plt.figure(figsize=(10,5))

for i in range(8):
  plt.subplot(1,8, i+1)
  plt.imshow(images[i])
  plt.axis("off")
plt.show()

# %%
#build convulational autoencoder

# Encoder
input_img = Input(shape=(64,64,3))

x = Conv2D(32, (3,3), activation='relu', padding='same')(input_img)
x = BatchNormalization()(x)
x = MaxPooling2D((2,2), padding='same')(x)

x = Conv2D(64, (3,3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2,2), padding='same')(x)

x = Conv2D(128, (3,3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
encoded = MaxPooling2D((2,2), padding='same')(x)

# %%
#decoder
x= Conv2D(
    64,(3,3),
    activation='relu',
    padding='same'
    )(encoded)
x = UpSampling2D((2,2))(x)
x = Conv2D(64,
           (3,3),
           activation='sigmoid',
           padding='same'
           )(x)

# %%
# Decoder
x = Conv2D(128, (3,3), activation='relu', padding='same')(encoded)
x = BatchNormalization()(x)
x = UpSampling2D((2,2))(x)

x = Conv2D(64, (3,3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = UpSampling2D((2,2))(x)

x = Conv2D(64, (3,3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = UpSampling2D((2,2))(x)

decoded = Conv2D(3, (3,3), activation='sigmoid', padding='same')(x)

# %%
#create model
autoencoder = Model(
    input_img,
    decoded
)

# %%
#compile model
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)

autoencoder.compile(
    optimizer='adam',
    loss='mse'
)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=2,
    min_lr=1e-6,
    verbose=1
)

# %%
loss='mse'

# %%
autoencoder.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_33 (Conv2D)              │ (None, 64, 64, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_21          │ (None, 64, 64, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_34 (Conv2D)              │ (None, 32, 32, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_22          │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_35 (Conv2D)              │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_23          │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_38 (Conv2D)              │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_24          │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_17 (UpSampling2D) │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_39 (Conv2D)              │ (None, 16, 16, 64)     │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_25          │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_18 (UpSampling2D) │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_40 (Conv2D)              │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_26          │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_19 (UpSampling2D) │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_41 (Conv2D)              │ (None, 64, 64, 3)      │         1,731 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 355,203 (1.35 MB)
#  Trainable params: 354,243 (1.35 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
history = autoencoder.fit(
    train_generator,
    epochs=60,
    validation_data=train_generator
)
# Out:
# Epoch 1/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 15s 59ms/step - loss: 0.0200 - val_loss: 0.0518
# Epoch 2/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 0.0115 - val_loss: 0.0289
# Epoch 3/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - loss: 0.0102 - val_loss: 0.0128
# Epoch 4/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 0.0090 - val_loss: 0.0092
# Epoch 5/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - loss: 0.0084 - val_loss: 0.0072
# Epoch 6/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0078 - val_loss: 0.0072
# Epoch 7/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 0.0077 - val_loss: 0.0070
# Epoch 8/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0074 - val_loss: 0.0066
# Epoch 9/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 0.0067 - val_loss: 0.0060
# Epoch 10/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - loss: 0.0067 - val_loss: 0.0069
# Epoch 11/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - loss: 0.0067 - val_loss: 0.0060
# Epoch 12/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0064 - val_loss: 0.0056
# Epoch 13/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - loss: 0.0064 - val_loss: 0.0056
# Epoch 14/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 0.0062 - val_loss: 0.0057
# Epoch 15/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: 0.0061 - val_loss: 0.0056
# Epoch 16/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - loss: 0.0059 - val_loss: 0.0056
# Epoch 17/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 0.0063 - val_loss: 0.0076
# Epoch 18/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 0.0059 - val_loss: 0.0055
# Epoch 19/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 67ms/step - loss: 0.0058 - val_loss: 0.0055
# Epoch 20/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 0.0057 - val_loss: 0.0055
# Epoch 21/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - loss: 0.0057 - val_loss: 0.0050
# Epoch 22/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - loss: 0.0055 - val_loss: 0.0056
# Epoch 23/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - loss: 0.0053 - val_loss: 0.0048
# Epoch 24/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - loss: 0.0054 - val_loss: 0.0050
# Epoch 25/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - loss: 0.0055 - val_loss: 0.0050
# Epoch 26/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 0.0051 - val_loss: 0.0049
# Epoch 27/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: 0.0053 - val_loss: 0.0053
# Epoch 28/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 0.0051 - val_loss: 0.0046
# Epoch 29/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: 0.0051 - val_loss: 0.0050
# Epoch 30/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 0.0051 - val_loss: 0.0049
# Epoch 31/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0051 - val_loss: 0.0046
# Epoch 32/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0049 - val_loss: 0.0050
# Epoch 33/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: 0.0048 - val_loss: 0.0045
# Epoch 34/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 0.0051 - val_loss: 0.0050
# Epoch 35/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - loss: 0.0048 - val_loss: 0.0044
# Epoch 36/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - loss: 0.0047 - val_loss: 0.0056
# Epoch 37/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 0.0047 - val_loss: 0.0044
# Epoch 38/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 0.0046 - val_loss: 0.0041
# Epoch 39/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 0.0046 - val_loss: 0.0044
# Epoch 40/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 0.0046 - val_loss: 0.0042
# Epoch 41/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - loss: 0.0046 - val_loss: 0.0044
# Epoch 42/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 0.0045 - val_loss: 0.0046
# Epoch 43/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - loss: 0.0047 - val_loss: 0.0041
# Epoch 44/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 0.0044 - val_loss: 0.0042
# Epoch 45/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 46/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 0.0046 - val_loss: 0.0341
# Epoch 47/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 0.0050 - val_loss: 0.0048
# Epoch 48/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 49/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - loss: 0.0044 - val_loss: 0.0053
# Epoch 50/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 0.0044 - val_loss: 0.0039
# Epoch 51/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: 0.0043 - val_loss: 0.0040
# Epoch 52/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 0.0045 - val_loss: 0.0040
# Epoch 53/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 54/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 55/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 56/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - loss: 0.0043 - val_loss: 0.0055
# Epoch 57/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 0.0042 - val_loss: 0.0040
# Epoch 58/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 0.0043 - val_loss: 0.0044
# Epoch 59/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 0.0042 - val_loss: 0.0038
# Epoch 60/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 0.0040 - val_loss: 0.0037
